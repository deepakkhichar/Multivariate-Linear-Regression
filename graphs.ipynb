# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(color_codes=True)

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data.csv')
print (df)
# Out:
#           metaOne          ts  sensorThree  sensorFour  sensorFive  sensorSix  \
# 0        15:55:21  2021-01-16          0.0         0.0         0.0       0.00
# 1        05:34:03  2021-01-18          0.0         0.0         0.0       0.00
# 2        14:11:13  2021-01-20          0.0         0.0         0.0       0.00
# 3        14:11:49  2021-01-20          0.0         0.0         0.0       0.00
# 4        09:41:37  2021-01-21          0.0         0.0         0.0      32.85
# ...           ...         ...          ...         ...         ...        ...
# 4353452  15:18:29  2021-04-05         53.0        79.0        91.0      28.50
# 4353453  12:23:38  2021-04-06         50.0        79.0        91.0      22.24
# 4353454  15:08:38  2021-04-06         52.0        79.0        91.0      26.43
# 4353455  19:57:05  2021-04-06         49.0        79.0        91.0      29.92
# 4353456  14:18:09  2021-04-06         51.0        79.0        91.0      27.27
#
#          sensorSeven
# ...

# %%
df.metaOne=pd.to_datetime(df.metaOne)

# %%
df.describe()
# Out:
#         sensorThree    sensorFour    sensorFive     sensorSix   sensorSeven
# count  4.353449e+06  4.353456e+06  4.353457e+06  4.353457e+06  4.353457e+06
# mean   5.624238e+01  9.356868e+01  1.066221e+02  3.989285e+01  2.543886e+01
# std    4.638106e+01  8.346598e+01  9.113163e+01  1.494352e+01  5.562070e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00 -1.970000e+00 -1.210000e+00
# 25%    2.600000e+01  4.000000e+01  5.100000e+01  3.073000e+01  2.187000e+01
# 50%    4.000000e+01  6.400000e+01  7.500000e+01  4.055902e+01  2.589000e+01
# 75%    7.600000e+01  1.250000e+02  1.390000e+02  4.938000e+01  2.930000e+01
# max    3.916000e+03  4.224000e+03  4.419000e+03  1.490000e+02  6.922000e+01

# %%
df.dtypes
# Out:
# metaOne        datetime64[ns]
# ts             datetime64[ns]
# sensorThree           float64
# sensorFour            float64
# sensorFive            float64
# sensorSix             float64
# sensorSeven           float64
# dtype: object

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.scatter(x='ts', y='sensorThree',data=df)
plt.xlabel('ts', fontsize=18)
plt.ylabel('sensorFour', fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.scatter(x='ts', y='sensorFive',data=df)
plt.xlabel('year')
plt.ylabel('sensorFive')
plt.xticks(rotation=90)
plt.show()

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.scatter(x='ts', y='sensorSix',data=df)
plt.xlabel('ts', fontsize=18)
plt.ylabel('sensorSix', fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.scatter(x='ts', y='sensorSeven',data=df)
plt.xlabel('year')
plt.ylabel('sensorThree')
plt.xticks(rotation=90)
plt.show()

# %%
df['combine'] = df['ts'] + df ['metaOne']
df
# Out:
#           metaOne          ts  sensorThree  sensorFour  sensorFive  sensorSix  \
# 0        15:55:21  2021-01-16          0.0         0.0         0.0       0.00
# 1        05:34:03  2021-01-18          0.0         0.0         0.0       0.00
# 2        14:11:13  2021-01-20          0.0         0.0         0.0       0.00
# 3        14:11:49  2021-01-20          0.0         0.0         0.0       0.00
# 4        09:41:37  2021-01-21          0.0         0.0         0.0      32.85
# ...           ...         ...          ...         ...         ...        ...
# 4353452  15:18:29  2021-04-05         53.0        79.0        91.0      28.50
# 4353453  12:23:38  2021-04-06         50.0        79.0        91.0      22.24
# 4353454  15:08:38  2021-04-06         52.0        79.0        91.0      26.43
# 4353455  19:57:05  2021-04-06         49.0        79.0        91.0      29.92
# 4353456  14:18:09  2021-04-06         51.0        79.0        91.0      27.27
#
# ...

# %%
df['combine'] = df['ts'] + df ['metaOne']
df
# Out:
#           metaOne          ts  sensorThree  sensorFour  sensorFive  sensorSix  \
# 0        15:55:21  2021-01-16          0.0         0.0         0.0       0.00
# 1        05:34:03  2021-01-18          0.0         0.0         0.0       0.00
# 2        14:11:13  2021-01-20          0.0         0.0         0.0       0.00
# 3        14:11:49  2021-01-20          0.0         0.0         0.0       0.00
# 4        09:41:37  2021-01-21          0.0         0.0         0.0      32.85
# ...           ...         ...          ...         ...         ...        ...
# 4353452  15:18:29  2021-04-05         53.0        79.0        91.0      28.50
# 4353453  12:23:38  2021-04-06         50.0        79.0        91.0      22.24
# 4353454  15:08:38  2021-04-06         52.0        79.0        91.0      26.43
# 4353455  19:57:05  2021-04-06         49.0        79.0        91.0      29.92
# 4353456  14:18:09  2021-04-06         51.0        79.0        91.0      27.27
#
# ...

# %%
sns.set(rc={'figure.figsize':(20,10)})
for c  in df.columns[2:]:
    ax = sns.lineplot(data = df, x='ts',y=c,label=c)
    plt.xticks(rotation=90)
    plt.legend()
plt.ylabel('All Sensors')
# Out:
# Text(0, 0.5, 'All Sensors')

# %%
sns.lineplot(data=df,x='ts',y='sensorThree')
# Out:
# <AxesSubplot:xlabel='ts', ylabel='sensorThree'>

# %%
plt.scatter(df.sensorThree , df.sensorFive)

plt.rcParams['figure.figsize'] = (20,10)

plt.xlabel('Sensor Three')
plt.ylabel('sensorFive')

plt.show()

# %%
plt.scatter(df.sensorThree , df.sensorSix)

plt.rcParams['figure.figsize'] = (20,10)

plt.xlabel('Sensor Three')
plt.ylabel('sensorSix')

plt.show()

# %%
plt.scatter(df.sensorThree , df.sensorSeven)

plt.rcParams['figure.figsize'] = (20,10)

plt.xlabel('Sensor Three')
plt.ylabel('sensorSeven')

plt.show()

# %%
plt.scatter(df.sensorFour , df.sensorFive)

plt.rcParams['figure.figsize'] = (20,10)

plt.xlabel('SensorFour')
plt.ylabel('sensorFive')

plt.show()

# %%
plt.scatter(df.sensorFour , df.sensorSix)

plt.rcParams['figure.figsize'] = (20,10)

plt.xlabel('SensorFour')
plt.ylabel('sensorSix')

plt.show()

# %%
plt.scatter(df.sensorFour , df.sensorSeven)

plt.rcParams['figure.figsize'] = (20,10)

plt.xlabel('SensorFour')
plt.ylabel('sensorSeven')

plt.show()
